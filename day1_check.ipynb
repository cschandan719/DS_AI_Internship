# %%
import sys
print("Setup Complete!")
print("Current Python Version:", sys.version)
# Out:
# Setup Complete!
# Current Python Version: 3.11.8 (tags/v3.11.8:db85d51, Feb  6 2024, 22:03:32) [MSC v.1937 64 bit (AMD64)]
