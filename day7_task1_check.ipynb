# %%
# Ask user for input
name = input("Enter your name: ")
goal = input("Enter your Daily Goal: ")

# Append data to journal.txt
with open("journal.txt", "a") as file:
    file.write(f"Name: {name} | Daily Goal: {goal}\n")

print("Entry saved successfully!")
