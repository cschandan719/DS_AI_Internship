# %%
item_name = "phone"     
quantity = 2             
price = 599.99          
in_stock = True         


print("Item:", item_name, ", Qty:", quantity, ", Price:", price, ", Available:", in_stock)


total_cost = quantity * price

# Print total cost
print("Total Cost:", total_cost)
# Out:
# Item: phone , Qty: 2 , Price: 599.99 , Available: True
# Total Cost: 1199.98
