# %%
# ask for user's name
name = input("Enter your name: ")

# ask for current age
age = input("Enter your current age: ")

# Convert age to integer
age = int(age)

# Calculate age in 2030 
new_age = age + 4

print("Hey", name + ", you will be", new_age, "years old in 2030!")
# Out:
# Hey chnadan, you will be 27 years old in 2030!

# %%
total_bill = float(input("Enter total bill amount: "))

num_people = int(input("Enter number of people: "))

share = total_bill / num_people

# result
print(f"Total Bill: {total_bill}. Each person pays: {share}")

# Bonus: Verify data types
print("Data type of total_bill:", type(total_bill))
print("Data type of num_people:", type(num_people))
print("Data type of share:", type(share))
# Out:
# Total Bill: 506.0. Each person pays: 101.2
# Data type of total_bill: <class 'float'>
# Data type of num_people: <class 'int'>
# Data type of share: <class 'float'>

# %%
item_name = "Laptop"     
quantity = 2             
price = 599.99          
in_stock = True         


print("Item:", item_name, ", Qty:", quantity, ", Price:", price, ", Available:", in_stock)


total_cost = quantity * price

# Print total cost
print("Total Cost:", total_cost)
# Out:
# Item: Laptop , Qty: 2 , Price: 599.99 , Available: True
# Total Cost: 1199.98
