# %% [markdown]
# Machine Learning is a method where computers learn patterns from data instead of being given fixed rules by programmers. In traditional programming, developers write specific instructions to solve a problem. In Machine Learning, the computer is given data and correct answers, and it learns the rules or patterns by itself. After learning, the model can make predictions or decisions when it sees new data. This is widely used in applications like recommendation systems, spam detection, and image recognition.
