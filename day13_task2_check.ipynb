# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("housing_data.csv")

plt.figure()
sns.scatterplot(x=df["Area_sqft"], y=df["Price"])
plt.title("Area vs Price")
plt.xlabel("Square Footage")
plt.ylabel("Price")
plt.show()

plt.figure()
sns.boxplot(x=df["City"], y=df["Price"])
plt.title("City vs Price")
plt.show()

print("Observation: As house size increases, price seems to increase.")
# Out:
# Observation: As house size increases, price seems to increase.
