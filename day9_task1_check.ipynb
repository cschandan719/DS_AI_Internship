# %%
import pandas as pd

products = pd.Series(
    [700, 150, 300],
    index=["Laptop", "Mouse", "Keyboard"]
)

print("Full Series:\n", products)

print("\nPrice of Laptop:", products["Laptop"])

print("\nFirst two products:\n", products.iloc[:2])
