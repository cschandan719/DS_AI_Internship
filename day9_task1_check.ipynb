# %%
import pandas as pd

products = pd.Series(
    [700, 150, 300],
    index=["Laptop", "Mouse", "Keyboard"]
)

print("Full Series:\n", products)

print("\nPrice of Laptop:", products["Laptop"])

print("\nFirst two products:\n", products.iloc[:2])
# Out:
# Full Series:
#  Laptop      700
# Mouse       150
# Keyboard    300
# dtype: int64
#
# Price of Laptop: 700
#
# First two products:
#  Laptop    700
# Mouse     150
# dtype: int64
