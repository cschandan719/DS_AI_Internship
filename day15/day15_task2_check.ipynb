# %%
p_heads = 1/2
p_six = 1/6
p_independent = p_heads * p_six

print("Independent probability (Heads AND 6):", p_independent)

p_first_red = 5/10
p_second_red = 4/9
p_dependent = p_first_red * p_second_red

print("Dependent probability (Both Red):", p_dependent)
# Out:
# Independent probability (Heads AND 6): 0.08333333333333333
# Dependent probability (Both Red): 0.2222222222222222
